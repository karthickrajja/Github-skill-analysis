# %%
import pandas as pd
import requests as rq
from api import getUser
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 3
#       1 import pandas as pd
#       2 import requests as rq
# ----> 3 from api import getUser
#
# ModuleNotFoundError: No module named 'api'
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
skills = {"Python": ["python"],"SQL": ["sql", "mysql", "postgres"],"Pandas": ["pandas"],"NumPy": ["numpy"],"FastAPI": ["fastapi"],"Docker": ["docker"],"Git": ["git"]}

words = ['analysis-data-science-books', 'analysis top reviews book for data science', 'python' , 'analyzed-real-data-to-identify-key-skills-for-data-analysts', 'examined skills required for data analyst positions advertised on google jobs using real-world data from the api. ', 'automated-data-pipeline-and-analysis-for-indian-small-cardamom-prices', 'automating the collection, storage, and visualization of indian small cardamom prices. it scrapes data from the indian spices board, stores it in google bigquery, and uses looker studio for visualization. this helps farmers and traders analyze market trends easily', 'bangalore-house-price-prediction', 'bangalore house price prediction with the help of a few parameters like availability, size, total square feet, bath, location, etc', 'big-mart-sales-prediction', 'breast_cancer-classification-', 'classification breast_cancer by using features such as cl.thickness,cell.size,cell.shape,marg.adhesion,epith.c.size,bare.nuclei,bl.cromatin', 'car-price-prediction', 'prediction car price by using given variables', 'chart-bot-machine-learning-', 'an ai chat bot which can interact about machine learning ', 'chatgpt', 'chun-prediction', 'predict behavior to retain customers. you can analyze all relevant customer data and develop focused customer retention programs', 'customer-sentiment-analysis', 'sentiment-based binary classification model (positive/ negative) for customer product review on amazon', 'customer-yearly-amount-spend-prediction', 'customers-yearly-amount-spend-prediction', 'predicting  yearly amount spend of a customer  (e-commerce dataset)', 'face-identification-model', 'flight-price-prediction', 'github-skill-analysis', 'github-skill-analyze', 'machine-learning-pipeline-for-beginners', 'a beginner level machine learning pipeline covering all basic steps.', 'price-prediction-for-pre-owned-cars', 'price prediction for pre-owned cars by using car dekho dataset', 'product-return', 'product-return-classification', 'model that classifies the product return of the online retail store. which contains features like order_date, delivery_date, item_id, item_size, item_color, brand_id, item_price, user_id, user_title, user_dob, user_state, user_reg_date with 1,00,00 data.', 'scraping-amazon-product-review-', 'scraping-flipkart-product-page', 'think-school-youtube-channel-analysis-using-youtube-api', 'transfer-learning-using-tensorflow', 'transfer learning using tensorflow']

# %%
for i , j in skills.items():
    print(i)
# Out:
# Python
# SQL
# Pandas
# NumPy
# FastAPI
# Docker
# Git

# %%
for i , j in skills.items():
    for skill in j:
        if skill in words:
            print(i, "Yes")
            break
    else :
        print (i , "No" )
# Out:
# Python Yes
# SQL No
# Pandas No
# NumPy No
# FastAPI No
# Docker No
# Git No

# %%
def check_skills(words ):
    skills = {"Python": ["python"],"SQL": ["sql", "mysql", "postgres"],"Pandas": ["pandas"],"NumPy": ["numpy"],"FastAPI": ["fastapi"],"Docker": ["docker"],"Git": ["git"]}
    for i , j in skills.items():
        for skill in j:
            if skill in words:
                print(i, "Yes")
                break
        else :
            print (i , "No" )

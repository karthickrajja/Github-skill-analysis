# %%
import pandas as pd
import numpy as np

# %%
data = {"Name":["Mani","Taaj","Ragul"],"age":[10,0,0]}

# %%
df = pd.DataFrame(data)

# %%
df.loc[:,["Name","age"]]
# Out:
#     Name  age
# 0   Mani   10
# 1   Taaj    0
# 2  Ragul    0

# %%
df.iloc[:,0:1]
# Out:
#     Name
# 0   Mani
# 1   Taaj
# 2  Ragul
